# %% [markdown]
# # Module 1 - Final Project

# %%
# Imports
import requests
import pandas as pd
from bs4 import BeautifulSoup
import re
import gspread
from oauth2client.service_account import ServiceAccountCredentials
import tweepy as tw
import json

# %%
# Base table scraped
# Retrieve table of European metal festivals of 2019
url = 'https://www.festival-alarm.com/us/Categories/Metal-festivals/(year)/2019'

try:
    html = requests.get(url).content
except requests.exceptions.HTTPError as errh:
    print ("Http Error:",errh)
except requests.exceptions.ConnectionError as errc:
    print ("Error Connecting:",errc)
except requests.exceptions.Timeout as errt:
    print ("Timeout Error:",errt)
except requests.exceptions.RequestException as err:
    print ("OOps: Something Else",err)

soup = BeautifulSoup(html, 'html')
fest_table = soup.find('table', {'class': 'festival_table'})
#rows = [row.text.strip().split('\n') for row in fest_table.find_all('tr')]
colnames = ['Name', 'Dates', 'Duration', 'Environment', 'Genres', 'Country', 'Venue', 'Price']
#data = rows[1:]
# Columns data
fest_names = [name.text.strip() for name in fest_table.find_all('td', {'class': 'event-title'})]
genres = [genre.text.strip() for genre in fest_table.find_all('td', {'class': 'event-genre'})]
countries = [country.text.strip() for country in fest_table.find_all('td', {'class': 'event_country'})]
venues = [''.join(venue.text.strip().split('\n')) for venue in fest_table.find_all('td', {'class': 'event-venue'})]
prices = [float(price.text.strip().replace('€ ', '').replace(',', '').replace('n/a', '0.00')) for price in fest_table.find_all('td', {'class': 'ticket_price'})]
durations = [''.join(re.findall(r'\d{1} day', duration.text)) for duration in fest_table.find_all('tr', {'class': 'event-wrapper'})]
dates = [' - '.join(re.findall(r'\d{2}/\d{2}', date.text)) for date in fest_table.find_all('tr', {'class': 'event-wrapper'})]
envs = [''.join(re.findall(r'indoor|outdoor', env.text)) for env in fest_table.find_all('tr', {'class': 'event-wrapper'})]
#visitors = [re.findall(r'^\d+|no data', visitor.text) for visitor in fest_table.find_all('tr', {'class': 'event-wrapper'})]

# %%
# Create the base DataFrame
df = pd.DataFrame(columns=colnames)
df['Name'] = fest_names
df['Dates'] = dates
df['Duration'] = durations
df['Environment'] = envs
df['Genres'] = genres
df['Country'] = countries
df['Venue'] = venues
df['Price'] = prices
df = df[df['Price'].between(90.00, 340.00)].sort_values(by='Price', ascending=False).set_index('Name')
df
# Out:
#                                  Dates Duration Environment  \
# Name
# Copenhell                06/19 - 06/22    4 day     outdoor
# Sweden Rock Festival     06/05 - 06/08    4 day     outdoor
# Wacken Open Air          08/01 - 08/03    3 day     outdoor
# Graspop Metal Meeting    06/21 - 06/23    3 day     outdoor
# Inferno Festival         04/18 - 04/21    4 day      indoor
# Bloodstock Open Air      08/08 - 08/11    4 day     outdoor
# Metaldays Festival       07/21 - 07/27    7 day     outdoor
# Download Festival (GB)   06/14 - 06/16    3 day     outdoor
# Sabaton Open Air         08/14 - 08/17    4 day     outdoor
# Download Festival (ES)   06/28 - 06/30    3 day     outdoor
# Alcatraz Festival        08/09 - 08/11    3 day     outdoor
# Hammerfest (GB)          03/21 - 03/24    4 day      indoor
# Tuska Open Air           06/28 - 06/30    3 day     outdoor
# Resurrection Festival    07/03 - 07/06    4 day     outdoor
# Metal Hammer Paradise    11/08 - 11/09    2 day      indoor
# Summer Breeze            08/14 - 08/17    4 day     outdoor
# Netherlands Deathfest    05/03 - 05/05    3 day      indoor
# Bang Your Head Festival  07/11 - 07/13    3 day     outdoor
# Resurrection Festival    137.00
# Metal Hammer Paradise    134.00
# Summer Breeze            133.00
# Netherlands Deathfest    123.00
# Bang Your Head Festival  119.00
# Motocultor Festival      119.00
# Mystic Festival          118.00
# Hellfest Open Air        118.00
# Rockharz Festival        110.00
# Full Force Festival      109.00
# Desertfest               109.00
# Euroblast Festival       109.00
# Metal On The Hill        102.49
# Metal Park Walsrode      100.00
# Keep It True Festival     99.00
# Dong Open Air             97.18
# Rock Hard Festival        97.00
# Eindhoven Metal Meeting   93.00
# Wolfszeit Festival        91.90
# Brutal Assault Festival   90.00
# AREA 53 Festival          90.00

# %%
# Google Sheet with lineups from selected festivals
# use creds to create a client to interact with the Google Drive API
scope = ['https://spreadsheets.google.com/feeds',
'https://www.googleapis.com/auth/drive']
creds = ServiceAccountCredentials.from_json_keyfile_name('client_secret.json', scope)
client = gspread.authorize(creds)

sheet = client.open("2019_metal_fests_lineup").sheet1

# Extract and print all of the values
festivals = sheet.get_all_records()
lineups = [[fest['lineup']] for fest in list_of_hashes]

lineups_dict = {fest['festival']: fest['lineup'] for fest in list_of_hashes}
df['Bands'] = lineups_dict.values()
df
# Out:
#                                  Dates Duration Environment  \
# Name
# Copenhell                06/19 - 06/22    4 day     outdoor
# Sweden Rock Festival     06/05 - 06/08    4 day     outdoor
# Wacken Open Air          08/01 - 08/03    3 day     outdoor
# Graspop Metal Meeting    06/21 - 06/23    3 day     outdoor
# Inferno Festival         04/18 - 04/21    4 day      indoor
# Bloodstock Open Air      08/08 - 08/11    4 day     outdoor
# Metaldays Festival       07/21 - 07/27    7 day     outdoor
# Download Festival (GB)   06/14 - 06/16    3 day     outdoor
# Sabaton Open Air         08/14 - 08/17    4 day     outdoor
# Download Festival (ES)   06/28 - 06/30    3 day     outdoor
# Alcatraz Festival        08/09 - 08/11    3 day     outdoor
# Hammerfest (GB)          03/21 - 03/24    4 day      indoor
# Tuska Open Air           06/28 - 06/30    3 day     outdoor
# Resurrection Festival    07/03 - 07/06    4 day     outdoor
# Metal Hammer Paradise    11/08 - 11/09    2 day      indoor
# Summer Breeze            08/14 - 08/17    4 day     outdoor
# Netherlands Deathfest    05/03 - 05/05    3 day      indoor
# Bang Your Head Festival  07/11 - 07/13    3 day     outdoor
# Motocultor Festival      08/15 - 08/18    4 day     outdoor
# Mystic Festival          06/25 - 06/26    2 day     outdoor
# Hellfest Open Air        06/21 - 06/23    3 day     outdoor
# Rockharz Festival        07/03 - 07/06    4 day     outdoor
# Full Force Festival      06/28 - 06/30    3 day     outdoor
# Desertfest               05/03 - 05/05    3 day      indoor
# Euroblast Festival               09/29    1 day      indoor
# Metal On The Hill        08/16 - 08/17    2 day      indoor
# Metal Park Walsrode      06/06 - 06/08    3 day     outdoor
# Keep It True Festival    04/26 - 04/27    2 day      indoor
# Dong Open Air            07/11 - 07/13    3 day     outdoor
# Rock Hard Festival       06/07 - 06/09    3 day     outdoor
# Eindhoven Metal Meeting  12/13 - 12/14    2 day      indoor
# Wolfszeit Festival       08/22 - 08/24    3 day     outdoor
# Brutal Assault Festival  08/07 - 08/10    4 day     outdoor
# AREA 53 Festival         07/11 - 07/13    3 day     outdoor
#
#                                                                     Genres  \
# Name
# Copenhell                                                Folk, Metal, Rock
# Sweden Rock Festival         Hardcore (Metal), Metal, Medieval, Punk, Rock
# Download Festival (GB)   Donington Park Derby,                         ...
# Sabaton Open Air               Falun,                              SE79130
# Download Festival (ES)   Caja Mágica Avenida Madrid Capital de España 7...
# Alcatraz Festival            Kortrijk,                              BE8500
# Hammerfest (GB)          Presthaven Beach Resort Prestatyn,            ...
# Tuska Open Air           Koksikatu Helsinki,                           ...
# Resurrection Festival    Av Ramón Canosa Vivero,                       ...
# Metal Hammer Paradise    Ferienpark Weissenhäuser Strand Seestr. 1 Olde...
# Summer Breeze            Dinkelsbühl,                              DE91550
# Netherlands Deathfest    Poppodium 013 Veemarktstraat 44 Tilburg,      ...
# Bang Your Head Festival  Messegelände Balingen Ausstellungsgel. Stetten...
# Motocultor Festival      Site de Kerboulard Saint-Nolff,               ...
# Mystic Festival          Tauron Arena Krakau,                          ...
# Hellfest Open Air            Clisson,                              FR44190
# Rockharz Festival        Flugplatz Ballenstedt Ballenstedt,            ...
# Full Force Festival      Ferropolis Ferropolisstraße 1 Gräfenhainichen,...
# Desertfest               Arena Berlin Eichenstraße 4 Berlin,           ...
# Euroblast Festival       Essigfabrik Siegburger Straße 110 Köln,       ...
# Metal On The Hill        Schlossberg Graz Grazer Schloßberg Graz,      ...
# Metal Park Walsrode         Walsrode,                              DE29664
# Keep It True Festival    Tauberfrankenhalle Hauptstrasse 1 Lauda-Königs...
# Dong Open Air            Halde Norddeutschland (Dongberg) Geldernsche S...
# Rock Hard Festival       Amphitheater Gelsenkirchen Grothusstr. 201 Gel...
# Eindhoven Metal Meeting  EFFENAAR Dommelstraat 2 Eindhoven,            ...
# Wolfszeit Festival       Ferienland Crispendorf Crispendorf,           ...
# Brutal Assault Festival  Festung Josefov Jaroměř,                      ...
# AREA 53 Festival         VAZS - Schladnitz Leoben Schladnitzstraße 53 L...
#
#                           Price  \
# Name
# Copenhell                340.00
# Sweden Rock Festival     286.00
# Wacken Open Air          221.00
# Graspop Metal Meeting    210.00
# Inferno Festival         199.00
# Bloodstock Open Air      176.00
# Metaldays Festival       175.00
# Download Festival (GB)   164.00
# Sabaton Open Air         160.00
# Download Festival (ES)   155.00
# Alcatraz Festival        150.00
# Hammerfest (GB)          140.00
# Tuska Open Air           139.00
# Resurrection Festival    137.00
# Metal Hammer Paradise    134.00
# Summer Breeze            133.00
# Netherlands Deathfest    123.00
# Bang Your Head Festival  119.00
# Motocultor Festival      119.00
# Mystic Festival          118.00
# Hellfest Open Air        118.00
# Rockharz Festival        110.00
# Full Force Festival      109.00
# Desertfest               109.00
# Euroblast Festival       109.00
# Metal On The Hill        102.49
# Metal Park Walsrode      100.00
# Keep It True Festival     99.00
# Dong Open Air             97.18
# Rock Hard Festival        97.00
# Eindhoven Metal Meeting   93.00
# Wolfszeit Festival        91.90
# Brutal Assault Festival   90.00
# AREA 53 Festival          90.00
#
#                                                                      Bands
# Name
# Copenhell                Tool,Slipknot,Scorpions,Slash featuring Myles ...
# Sweden Rock Festival     A.C.T,Amon Amarth,Unleashed,Arch Enemy,At the ...
# Wacken Open Air          Airbourne,All Hail The Yeti,Avatar,Critical Me...
# Graspop Metal Meeting    Agnostic Front,Amon Amarth,Anthrax,Bleed From ...
# Inferno Festival         Taake,1349,Vomitory,Gaahls Wyrd,Hypocrisy,Cara...
# Bloodstock Open Air      Rotting Christ,Ten Ton Slug,Footprints in the ...
# Metaldays Festival       Dimmu Borgir,Tarja,Demons & Wizards,Hypocrisy,...
# Download Festival (GB)   Def Leppard,Slash,Whitesnake,Clutch,Blackberry...
# Sabaton Open Air         Kardinal Sin,Rave The Reqviem,PreHistoric Anim...
# Download Festival (ES)   Vita Imana,Papa Roach,Comeback Kid,Children Of...
# Alcatraz Festival        Saxon,Opeth,Uriah Heep,Queensrÿche,Vio-lence,S...
# Hammerfest (GB)          Absolva,Arkham Witch,Ashen Crown,Battalions,Bl...
# Tuska Open Air           Slayer,Anthrax,Cult of Luna,Battle Beast,Annek...
# Resurrection Festival    Kvelertak,Ignite,Municipal Waste,Bury Tomorrow...
# Metal Hammer Paradise    Onkel Tom Angelripper,Grave Digger,Saltatio Mo...
# Summer Breeze            Parkway Drive,Bullet for My Valentine,Avantasi...
# Netherlands Deathfest    Rippikoulu,Anaal Nathrakh,Cryptopsy,Brujeria,E...
# Bang Your Head Festival  Armored Saint,Attic,Audrey Horne,Beast In Blac...
# Motocultor Festival      Excalibur – The Celtic Rock Opera,Corvus Corax...
# Mystic Festival          Slipknot,In Flames,Amon Amarth,Powerwolf,Testa...
# Hellfest Open Air        Manowar,Dropkick Murphys,Dream Theatre,Demons ...
# Rockharz Festival        Brothers of Metal,Combichrist,From North,J.B.O...
# Full Force Festival      Alcest,Amenra,Amorphis,Animals As Leaders,Anni...
# Desertfest               ALL THEM WITCHES,WITCH,COLOUR HAZE,EARTHLESS,T...
# Euroblast Festival       BETWEEN THE BURIED AND ME,TWELVE FOOT NINJA,BE...
# Metal On The Hill        Battle Beast,Ensiferum,Hammerfall,Alien Weapon...
# Metal Park Walsrode
# Keep It True Festival    A Tribute To Mark Shelton,Agent Steel,Anthem,A...
# Dong Open Air            Alestorm,Steel Panther,Kataklysm,Gloryhammer,I...
# Rock Hard Festival       Chapel of Disease,Lizzy Borden,The Idiots,Tyge...
# Eindhoven Metal Meeting  Lucifericon,Asagraum,Acrostichon,Bodyfarm,Noct...
# Wolfszeit Festival       Varg,Arkona,Finsterforst,In Twilight's Embrace...
# Brutal Assault Festival  ABORTED,AFTER THE BURIAL,AGNOSTIC FRONT,ALIEN ...
# AREA 53 Festival         Children of Bodom,Dark Tranquillity,Dimmu Borg...

# %%
# Twitter API
# Count the number of tweets with the festival hashtag

# Utility JSON function
def getJSONValue(val):
    with open('twitter_secret.json') as file:
        data = json.load(file)
        return data[val]

# Authentification
consumer_key = getJSONValue('API_KEY')
consumer_secret = getJSONValue('API_SECRET')
access_token = getJSONValue('ACCESS_TOKEN')
access_token_secret = getJSONValue('ACCESS_TOKEN_SECRET')

auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)

hashtags = ['#' + name.lower().split('(')[0].strip().replace(' ', '') + '2019' for name in df.index.tolist()]
date_since = "2018-07-01"

def getTweetsCount(hashtag):
    tweets = tw.Cursor(api.search,
                  q=hashtag,     
                  lang="en",
                  since=date_since).items()
    return len(list(tweets))

trend_counts = [getTweetsCount(name) for name in hashtags]

# %%
# Scraping from Twitter search page directly
from twitterscraper import query_tweets

trend_counts = [len(query_tweets(f'{hashtag}', 10)) for hashtag in hashtags]
trend_counts
